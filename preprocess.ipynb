# %%
import os
import re
import underthesea
from tqdm import tqdm

# %%
def normalize_vietnamese_text(text):
   
   text = text.lower().strip()
   text = re.sub(r"\s+", " ", text)  # Normalize multiple spaces

   # Keep only allowed characters (letters, numbers, punctuation)
   text = re.sub(r"[^a-zA-ZÀ-Ỹà-ỹ0-9,._!?;:/() ]+", "", text)

   # Fix punctuation spacing (ensure no space before, but one space after)
   text = re.sub(r"\s*,\s*", ", ", text)  # Comma: " , " → ", "
   text = re.sub(r"\s*;\s*", "; ", text)  # Semicolon: " ; " → "; "
   text = re.sub(r"\s*:\s*", ": ", text)  # Colon: " : " → ": "
   text = re.sub(r"\s*\.\s*", ". ", text)  # Period: " . " → ". "

   # Preserve numbered lists (ensure "2." remains part of the list, but not merge with previous sentence)
   text = re.sub(r"(?<=\w\.)\s+(\d+)\.", r" \1.", text)  # "X. 2." → "X. 2."

   # Ensure no extra spaces at the end
   text = text.strip()

   return text

def tokenize_vietnamese_text(text):
   
   tokens = underthesea.word_tokenize(text, format="text").split()  # Tokenize text
   return " ".join(tokens)  # Convert tokens back to text

def preprocess_vietnamese_folder(input_folder, output_folder):
   
   if not os.path.exists(output_folder):
      os.makedirs(output_folder)

   for filename in os.listdir(input_folder):
      if filename.endswith(".txt"):  
         input_path = os.path.join(input_folder, filename)
         output_path = os.path.join(output_folder, filename)

         
         with open(input_path, "r", encoding="utf-8") as file:
            raw_text = file.read()

         # Normalize text 
         cleaned_text = normalize_vietnamese_text(raw_text)

         # Tokenize text 
         processed_text = tokenize_vietnamese_text(cleaned_text)

         with open(output_path, "w", encoding="utf-8") as file:
            file.write(processed_text)

         print(f"Processed: {filename} → Saved to {output_path}")

# %%
input_folder = r"D:\ds_b3\NLP\xml_data\under2k"   
output_folder = r"D:\ds_b3\NLP\xml_data\under2k_cleaned"   

preprocess_vietnamese_folder(input_folder, output_folder)
# Out:
# Processed: 10015.txt → Saved to D:\ds_b3\NLP\xml_data\under2k_cleaned\10015.txt
# Processed: 10047.txt → Saved to D:\ds_b3\NLP\xml_data\under2k_cleaned\10047.txt
# Processed: 10106.txt → Saved to D:\ds_b3\NLP\xml_data\under2k_cleaned\10106.txt
# Processed: 10135.txt → Saved to D:\ds_b3\NLP\xml_data\under2k_cleaned\10135.txt
# Processed: 10185.txt → Saved to D:\ds_b3\NLP\xml_data\under2k_cleaned\10185.txt
# Processed: 10186.txt → Saved to D:\ds_b3\NLP\xml_data\under2k_cleaned\10186.txt
# Processed: 10317.txt → Saved to D:\ds_b3\NLP\xml_data\under2k_cleaned\10317.txt
# Processed: 10418.txt → Saved to D:\ds_b3\NLP\xml_data\under2k_cleaned\10418.txt
# Processed: 10461.txt → Saved to D:\ds_b3\NLP\xml_data\under2k_cleaned\10461.txt
# Processed: 10564.txt → Saved to D:\ds_b3\NLP\xml_data\under2k_cleaned\10564.txt
# Processed: 10573.txt → Saved to D:\ds_b3\NLP\xml_data\under2k_cleaned\10573.txt
# Processed: 10576.txt → Saved to D:\ds_b3\NLP\xml_data\under2k_cleaned\10576.txt
# Processed: 10599.txt → Saved to D:\ds_b3\NLP\xml_data\under2k_cleaned\10599.txt
# Processed: 10602.txt → Saved to D:\ds_b3\NLP\xml_data\under2k_cleaned\10602.txt
# Processed: 10605.txt → Saved to D:\ds_b3\NLP\xml_data\under2k_cleaned\10605.txt
# Processed: 10608.txt → Saved to D:\ds_b3\NLP\xml_data\under2k_cleaned\10608.txt
# Processed: 10609.txt → Saved to D:\ds_b3\NLP\xml_data\under2k_cleaned\10609.txt
# Processed: 10610.txt → Saved to D:\ds_b3\NLP\xml_data\under2k_cleaned\10610.txt
# Processed: 10611.txt → Saved to D:\ds_b3\NLP\xml_data\under2k_cleaned\10611.txt
# Processed: 10613.txt → Saved to D:\ds_b3\NLP\xml_data\under2k_cleaned\10613.txt
# Processed: 10614.txt → Saved to D:\ds_b3\NLP\xml_data\under2k_cleaned\10614.txt
# Processed: 10617.txt → Saved to D:\ds_b3\NLP\xml_data\under2k_cleaned\10617.txt
# Processed: 10620.txt → Saved to D:\ds_b3\NLP\xml_data\under2k_cleaned\10620.txt
# Processed: 10646.txt → Saved to D:\ds_b3\NLP\xml_data\under2k_cleaned\10646.txt
# Processed: 10653.txt → Saved to D:\ds_b3\NLP\xml_data\under2k_cleaned\10653.txt
# Processed: 10659.txt → Saved to D:\ds_b3\NLP\xml_data\under2k_cleaned\10659.txt
# Processed: 10663.txt → Saved to D:\ds_b3\NLP\xml_data\under2k_cleaned\10663.txt
# Processed: 10669.txt → Saved to D:\ds_b3\NLP\xml_data\under2k_cleaned\10669.txt
# Processed: 10671.txt → Saved to D:\ds_b3\NLP\xml_data\under2k_cleaned\10671.txt
# Processed: 10672.txt → Saved to D:\ds_b3\NLP\xml_data\under2k_cleaned\10672.txt
# Processed: 10675.txt → Saved to D:\ds_b3\NLP\xml_data\under2k_cleaned\10675.txt
# Processed: 10677.txt → Saved to D:\ds_b3\NLP\xml_data\under2k_cleaned\10677.txt
# Processed: 10678.txt → Saved to D:\ds_b3\NLP\xml_data\under2k_cleaned\
txt → Saved to D:\ds_b3\NLP\xml_data\under2k_cleaned\9443.txt
# Processed: 9460.txt → Saved to D:\ds_b3\NLP\xml_data\under2k_cleaned\9460.txt
# Processed: 9461.txt → Saved to D:\ds_b3\NLP\xml_data\under2k_cleaned\9461.txt
# Processed: 9470.txt → Saved to D:\ds_b3\NLP\xml_data\under2k_cleaned\9470.txt
# Processed: 9471.txt → Saved to D:\ds_b3\NLP\xml_data\under2k_cleaned\9471.txt
# Processed: 9472.txt → Saved to D:\ds_b3\NLP\xml_data\under2k_cleaned\9472.txt
# Processed: 9473.txt → Saved to D:\ds_b3\NLP\xml_data\under2k_cleaned\9473.txt
# Processed: 9476.txt → Saved to D:\ds_b3\NLP\xml_data\under2k_cleaned\9476.txt
# Processed: 9480.txt → Saved to D:\ds_b3\NLP\xml_data\under2k_cleaned\9480.txt
# Processed: 9516.txt → Saved to D:\ds_b3\NLP\xml_data\under2k_cleaned\9516.txt
# Processed: 9527.txt → Saved to D:\ds_b3\NLP\xml_data\under2k_cleaned\9527.txt
# Processed: 9533.txt → Saved to D:\ds_b3\NLP\xml_data\under2k_cleaned\9533.txt
# Processed: 9546.txt → Saved to D:\ds_b3\NLP\xml_data\under2k_cleaned\9546.txt
# Processed: 9548.txt → Saved to D:\ds_b3\NLP\xml_data\under2k_cleaned\9548.txt
# Processed: 9565.txt → Saved to D:\ds_b3\NLP\xml_data\under2k_cleaned\9565.txt
# Processed: 9566.txt → Saved to D:\ds_b3\NLP\xml_data\under2k_cleaned\9566.txt
# Processed: 9568.txt → Saved to D:\ds_b3\NLP\xml_data\under2k_cleaned\9568.txt
# Processed: 9569.txt → Saved to D:\ds_b3\NLP\xml_data\under2k_cleaned\9569.txt
# Processed: 9577.txt → Saved to D:\ds_b3\NLP\xml_data\under2k_cleaned\9577.txt
# Processed: 9582.txt → Saved to D:\ds_b3\NLP\xml_data\under2k_cleaned\9582.txt
# Processed: 9585.txt → Saved to D:\ds_b3\NLP\xml_data\under2k_cleaned\9585.txt
# Processed: 9589.txt → Saved to D:\ds_b3\NLP\xml_data\under2k_cleaned\9589.txt
# Processed: 9594.txt → Saved to D:\ds_b3\NLP\xml_data\under2k_cleaned\9594.txt
# Processed: 9595.txt → Saved to D:\ds_b3\NLP\xml_data\under2k_cleaned\9595.txt
# Processed: 9600.txt → Saved to D:\ds_b3\NLP\xml_data\under2k_cleaned\9600.txt
# Processed: 9602.txt → Saved to D:\ds_b3\NLP\xml_data\under2k_cleaned\9602.txt
# Processed: 9608.txt → Saved to D:\ds_b3\NLP\xml_data\under2k_cleaned\9608.txt
# Processed: 9635.txt → Saved to D:\ds_b3\NLP\xml_data\under2k_cleaned\9635.txt
# Processed: 9685.txt → Saved to D:\ds_b3\NLP\xml_data\under2k_cleaned\9685.txt
# Processed: 9686.txt → Saved to D:\ds_b3\NLP\xml_data\under2k_cleaned\9686.txt
# Processed: 9713.txt → Saved to D:\ds_b3\NLP\xml_data\under2k_cleaned\9713.txt
# Processed: 9716.txt → Saved to D:\ds_b3\NLP\xml_data\under2k_cleaned\9716.txt
# Processed: 9721.txt → Saved to D:\ds_b3\NLP\xml_data\under2k_cleaned\9721.txt
# Processed: 9748.txt → Saved to D:\ds_b3\NLP\xml_data\under2k_cleaned\9748.txt
# Processed: 9773.txt → Saved to D:\ds_b3\NLP\xml_data\under2k_cleaned\9773.txt
# Processed: 9782.txt → Saved to D:\ds_b3\NLP\xml_data\under2k_cleaned\9782.txt
# Processed: 9787.txt → Saved to D:\ds_b3\NLP\xml_data\under2k_cleaned\9787.txt
# Processed: 9821.txt → Saved to D:\ds_b3\NLP\xml_data\under2k_cleaned\9821.txt
# Processed: 9897.txt → Saved to D:\ds_b3\NLP\xml_data\under2k_cleaned\9897.txt
# Processed: 9957.txt → Saved to D:\ds_b3\NLP\xml_data\under2k_cleaned\9957.txt

# %%
from underthesea import sent_tokenize, word_tokenize

# %%
def split_into_chunks(text, max_words=500):
   
   sentences = sent_tokenize(text)  
   chunks = []
   current_chunk = []
   current_length = 0

   for sentence in sentences:
      words = word_tokenize(sentence)  
      word_count = len(words)

      if current_length + word_count > max_words:
         # If adding this sentence exceeds max_words, save current chunk and start a new one
         if current_chunk:
            chunks.append(" ".join(current_chunk))
         current_chunk = [sentence]
         current_length = word_count
      else:
         # Otherwise, add sentence to the current chunk
         current_chunk.append(sentence)
         current_length += word_count

   if current_chunk:
      chunks.append(" ".join(current_chunk))

   return chunks

# %%
def chunk_and_token(input_folder, output_folder, max_words=300):

   if not os.path.exists(output_folder):
      os.makedirs(output_folder)

   file_list = [f for f in os.listdir(input_folder) if f.endswith(".txt")]

   for filename in tqdm(file_list, desc="Processing files"):
      input_path = os.path.join(input_folder, filename)
      output_path = os.path.join(output_folder, filename)

      with open(input_path, "r", encoding="utf-8") as file:
         text = file.read()

      chunks = split_into_chunks(text, max_words)

      with open(output_path, "w", encoding="utf-8") as file:
         for i, chunk in enumerate(chunks):
            file.write(f"### Chunk {i+1} ###\n{chunk}\n\n")

   print(f"Processed {len(file_list)} files and saved to '{output_folder}'.")

# %%
input_folder = r"D:\ds_b3\NLP\xml_data\under2k_cleaned"  
output_folder = r"D:\ds_b3\NLP\xml_data\under2k_chunked"  
chunk_and_token(input_folder, output_folder)
# Out:
# Processing files: 100%|██████████| 2676/2676 [01:44<00:00, 25.55it/s]
# Processed 2676 files and saved to 'D:\ds_b3\NLP\xml_data\under2k_chunked'.
